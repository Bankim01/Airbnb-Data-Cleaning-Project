# %% [markdown]
# ## Data Cleaning Project

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_csv('E:/Data Analytics Python Projects/Pandas Project/Pandas/Airbnb_Open_Data.csv' , dtype= 'unicode' )

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat       long        country  ... service fee minimum nights  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  object
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  object
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  object
#  8   long                            102591 non-null  object
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
df["license"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 102594    NaN
# 102595    NaN
# 102596    NaN
# 102597    NaN
# 102598    NaN
# Name: license, Length: 102599, dtype: object

# %% [markdown]
# #### Deleting redundant columns

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review'] 

columns_to_drop = ['id','reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license']

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 7

# %% [markdown]
# ##### Filtering Data

# %%
df[columns_to_keep]
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.shape
# Out:
# (102599, 26)

# %%
df1 = df.drop(columns= columns_to_drop)

# %%
df1
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df1.shape
# Out:
# (102599, 19)

# %%
df1.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %% [markdown]
# ##### Renaming the columns

# %%
df1.rename(columns = {'NAME' : 'Name'} , inplace=True)

# %%
df1.head()
# Out:
#                                                Name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                               NaN  85098326012
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat       long        country country code instant_bookable  \
# 0  40.64749  -73.97237  United States           US            FALSE
# ...

# %%
# Converting column names in lower case

new_column_name = []
for i in df1.columns:
    new_column_name.append(i.lower())

# %%
new_column_name
# Out:
# ['name',
#  'host id',
#  'host_identity_verified',
#  'host name',
#  'neighbourhood group',
#  'neighbourhood',
#  'lat',
#  'long',
#  'country',
#  'country code',
#  'instant_bookable',
#  'cancellation_policy',
#  'room type',
#  'construction year',
#  'price',
#  'service fee',
#  'minimum nights',
#  'number of reviews',
#  'last review']

# %%
# Naming columns with upper case
df1.columns = new_column_name

# %%
df1.head()
# Out:
#                                                name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                               NaN  85098326012
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat       long        country country code instant_bookable  \
# 0  40.64749  -73.97237  United States           US            FALSE
# ...

# %% [markdown]
# ##### Checking Duplicate data

# %%
df1.duplicated().sum()
# Out:
# np.int64(541)

# %%
# Drop duplicates
df1.drop_duplicates(inplace= True)

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### Removing NaN values

# %%
df1.isna().sum()
# Out:
# name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
df1.drop(columns= ['last review'] , inplace= True)

# %%
df1.isna().sum()
# Out:
# name                      250
# host id                     0
# host_identity_verified    289
# host name                 404
# neighbourhood group        29
# neighbourhood              16
# lat                         8
# long                        8
# country                   532
# country code              131
# instant_bookable          105
# cancellation_policy        76
# room type                   0
# construction year         214
# price                     247
# service fee               273
# minimum nights            400
# number of reviews         183
# dtype: int64

# %% [markdown]
# ##### Dropping NaN

# %%
df1.dropna(inplace= True)

# %%
df1.isna().sum()
# Out:
# name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# dtype: int64

# %% [markdown]
# ##### Cleanig individual columns

# %%
df1
# Out:
#                                                     name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 unconfirmed   Madaline            Brooklyn
# ...

# %%
df1["host_identity_verified"] = df1.host_identity_verified.str.capitalize()   # Converting "host_identity_verified" in Capitalized

# %%
df1
# Out:
#                                                     name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 Unconfirmed   Madaline            Brooklyn
# ...

# %%
df1.head()
# Out:
#                                                name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            Unconfirmed  Madaline            Brooklyn          Kensington
# 1               Verified     Jenna           Manhattan             Midtown
# 4               Verified    Lyndon           Manhattan         East Harlem
# 5               Verified  Michelle           Manhattan         Murray Hill
# 7            Unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat       long        country country code instant_bookable  \
# ...

# %%
df1["instant_bookable"]  # converting False=0 and True=1
# Out:
# 0         FALSE
# 1         FALSE
# 4         FALSE
# 5          TRUE
# 7         FALSE
#           ...
# 102029    FALSE
# 102030     TRUE
# 102031     TRUE
# 102032    FALSE
# 102040     TRUE
# Name: instant_bookable, Length: 99342, dtype: object

# %%
df1["instant_bookable"].apply(lambda x : 1 if x == True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         0
# 7         0
#          ..
# 102029    0
# 102030    0
# 102031    0
# 102032    0
# 102040    0
# Name: instant_bookable, Length: 99342, dtype: int64

# %%
df1["instant_bookable"] = df1["instant_bookable"].apply(lambda x : 1 if x == True else 0)

# %%
df1  # We can observe that index are not in proper sequence
# Out:
#                                                     name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 Unconfirmed   Madaline            Brooklyn
# ...

# %%
# Reseting index
df1.reset_index(inplace= True)

# %%
df1
# Out:
#         index                                              name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
df1["instant_bookable"].dtype
# Out:
# dtype('int64')

# %%
# Removing $ sign from "price" and "service fee". Also converting them into integer
df1["price"] = df1["price"].str.replace("$" , "")

# %%
df1["price"]
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 99337      822
# 99338      455
# 99339    1,078
# 99340      103
# 99341      982
# Name: price, Length: 99342, dtype: object

# %%
# Removing ','

df1["price"] = df1["price"].str.replace("," , "")

# %%
df1["price"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: object

# %%
# Removing spaces if any
df1["price"] = df1["price"].str.replace( " " , "")

# %%
df1["price"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: object

# %%
type(df1["price"])
# Out:
# pandas.core.series.Series

# %%
# Now Converting "price" column into integer

df1["price"].astype(int).dtype
# Out:
# dtype('int64')

# %%
df1["price"] = df1["price"].astype(int)

# %%
df1["price"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: int64

# %%
df1["price"].head()
# Out:
# 0     966
# 1     142
# 2     204
# 3     577
# 4    1060
# Name: price, dtype: int64

# %%
type(df1["price"][1])
# Out:
# numpy.int64

# %%
df1.head()
# Out:
#    index                                              name      host id  \
# 0      0                Clean & quiet apt home by the park  80014485718
# 1      1                             Skylit Midtown Castle  52335172823
# 2      4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3      5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4      7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            Unconfirmed  Madaline            Brooklyn          Kensington
# 1               Verified     Jenna           Manhattan             Midtown
# 2               Verified    Lyndon           Manhattan         East Harlem
# 3               Verified  Michelle           Manhattan         Murray Hill
# 4            Unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat       long        country country code  instant_bookable  \
# ...

# %% [markdown]
# ##### Now cleaning "service fee" as we did for "price" column

# %%
df1.head()
# Out:
#    index                                              name      host id  \
# 0      0                Clean & quiet apt home by the park  80014485718
# 1      1                             Skylit Midtown Castle  52335172823
# 2      4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3      5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4      7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            Unconfirmed  Madaline            Brooklyn          Kensington
# 1               Verified     Jenna           Manhattan             Midtown
# 2               Verified    Lyndon           Manhattan         East Harlem
# 3               Verified  Michelle           Manhattan         Murray Hill
# 4            Unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat       long        country country code  instant_bookable  \
# ...

# %%
df1['service fee']
# Out:
# 0        $193
# 1         $28
# 2         $41
# 3        $115
# 4        $212
#          ...
# 99337    $164
# 99338     $91
# 99339    $216
# 99340     $21
# 99341    $196
# Name: service fee, Length: 99342, dtype: object

# %%
df1['service fee'] = df1['service fee'].str.replace('$' , '').str.replace(' ' , '')

# %%
df1['service fee'] = df1['service fee'].astype(int)

# %%
df1['service fee'].dtypes
# Out:
# dtype('int64')

# %%
df1.drop(columns= 'index' , inplace= True)

# %%
df1
# Out:
#                                                    name      host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       host_identity_verified  host name neighbourhood group  \
# 0                Unconfirmed   Madaline            Brooklyn
# ...

# %% [markdown]
# #### Converting cleanead data into csv format

# %%
df1.to_csv("Cleaned Data.csv")

# %%
pd.read_csv("Cleaned Data.csv")
# Out:
#        Unnamed: 0                                              name  \
# 0               0                Clean & quiet apt home by the park
# 1               1                             Skylit Midtown Castle
# 2               2  Entire Apt: Spacious Studio/Loft by central park
# 3               3         Large Cozy 1 BR Apartment In Midtown East
# 4               4                                   BlissArtsSpace!
# ...           ...                                               ...
# 99337       99337            Cozy room in a 2B with backyard access
# 99338       99338                      An East Williamsburg Delight
# 99339       99339                      Cozy bedroom in williamsburg
# 99340       99340                            Spacious Room w/ 2 Bed
# 99341       99341                     Room in Queens, NY, near LGA.
#
#            host id host_identity_verified  host name neighbourhood group  \
# 0      80014485718            Unconfirmed   Madaline            Brooklyn
# ...
